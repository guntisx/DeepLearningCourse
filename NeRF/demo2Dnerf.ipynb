# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamwagh/nerf-toy/blob/main/notebook/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, let's try fitting a function to produce the image as a function of (X,Y) image coordinates.
#
# More details can be found [here](https://github.com/shubhamwagh/nerf-toy/blob/main/README.md).

# %%
# !pip install nerf-toy
# Out:
# Collecting nerf-toy
#   Downloading nerf_toy-1.0.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from nerf-toy) (4.11.0.86)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from nerf-toy) (2.18.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from nerf-toy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from nerf-toy) (0.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio->nerf-toy) (2.0.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->nerf-toy) (11.2.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->nerf-toy) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->nerf-toy) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->nerf-toy) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->nerf-toy) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->nerf-toy) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->nerf-toy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->nerf-toy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->nerf-toy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->nerf-toy) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->nerf-toy) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->nerf-toy) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->nerf-toy) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow->nerf-toy) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->nerf-toy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->nerf-toy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->nerf-toy) (0.1.2)
# Downloading nerf_toy-1.0.0-py3-none-any.whl (8.9 kB)
# Installing collected packages: nerf-toy
# Successfully installed nerf-toy-1.0.0

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from nerf_toy.data_loader import DataLoader
from nerf_toy.transforms import BasicEncodingTransform, PositionalEncodingTransform, GaussianFourierFeatureTransform
from nerf_toy.model import base_model
from nerf_toy.callback import PredictionVideoSaverCallback, PlotLossesAndMetricsCallback
from nerf_toy.metrics import PSNR, SSIM
from nerf_toy.utils import arr_to_image

# %%
#img_url = "https://unsplash.com/photos/MMRd58Fo_Mk/download?force=true&w=640"
img_url = "https://raw.githubusercontent.com/shubhamwagh/nerf-toy/main/data/lion_face.jpg"

# %%
basic_transform = BasicEncodingTransform() # Basic Mapping
poistional_encoding= PositionalEncodingTransform(multires=10) # Positional Encoding
fourier_feature_transform = GaussianFourierFeatureTransform(num_input_channels=2, mapping_size=128, scale=10) # Gaussian Fourier Feature Mapping

# %%
loader = DataLoader(uri=img_url, transform=fourier_feature_transform) # default transform=None means no mapping

# %%
yx_grid, target = loader.load_data()
print(yx_grid.shape)
print(target.shape)

plt.imshow(target[0])
plt.show()
# Out:
# (1, 256, 256, 256)
# (1, 256, 256, 3)

# %% [markdown]
# # Model and training code
#
# Our model is a coordinate-based multilayer perceptron. In this example, for each input image coordinate $(x,y)$, the model predicts the associated color $(r,g,b)$.
#
# ![Network diagram](https://raw.githubusercontent.com/shubhamwagh/nerf-toy/main/misc/network_diagram.png)
#
# Note: we use 2D convolutions with a kernel size of (1, 1), which act as "pointwise" convolutions. This is equivalent to a densely connected multilayer perceptron for each coordinate.
#
# Also, we use batchnorm to speed up convergence.

# %%
net = base_model(input_shape=yx_grid.shape[1:], output_dim=3, num_layers=4, num_channels=256) # basic nerf toy model

loss = 'mse'
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

psnr_metric = PSNR(max_value=1.0) # peak signal-to-noise ratio
ssim_metric = SSIM(max_value=1.0) # structured-similarity index

video_callback = PredictionVideoSaverCallback(yx_grid, target, every=1, video_path='/content') # Video frames saver callback
plot_callback = PlotLossesAndMetricsCallback() # Plot losses anad metrics callback

net.compile(optimizer=optimizer, loss=loss, metrics=[psnr_metric, ssim_metric])

hist = net.fit(x=yx_grid, y=target, epochs=500, verbose=0, callbacks=[video_callback, plot_callback])
# Out:
# Saving training convergence video.....
# Saved training convergence video as /content/training_convergence_0.mp4

# %%
# Inference using trained model
generated = net(yx_grid, training=False)
plt.imshow(arr_to_image(generated[0]))
plt.show()

# %%
# Display video inline
file = video_callback.saved_path
from IPython.display import HTML
from base64 import b64encode
mp4 = open(file, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'''
<video width=256 controls autoplay loop>
      <source src="{data_url}" type="video/mp4">
</video>''')
# Out:
# <video width=256 controls autoplay loop>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
